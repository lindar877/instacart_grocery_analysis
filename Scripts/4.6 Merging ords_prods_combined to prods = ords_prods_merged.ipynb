# %% [markdown]
# ## Contents
#
# 01. Checking the prods and ords_prods_combined data sets
# 02. Merging the prods and ords_prods_combined data sets
# 03. Consistency checks on merged data set

# %%
import pandas as pd
import numpy as np
import os

# %%
# importing order_products_combined data set

path = r'/Users/lindazhang/Instacart Basket Analysis'
df_ords_prods_combined = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %% [markdown]
# ## 01. Checking the prods and ords_prods_combined data sets

# %%
# importing just the columns I need from df_prods

vars_list = ['product_id', 'product_name', 'aisle_id', 'department_id', 'prices']
df_prods = pd.read_csv(os.path.join(path, '02 Data','Prepared Data','prods_cleaned.csv'), usecols = vars_list)

# %%
# checking the df_prods dataset

df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
# checking the shape of the df_prods data set

df_prods.shape
# Out:
# (49688, 5)

# %%
# checking the df_ords_prods_combined data set

df_ords_prods_combined.head()
# Out:
#    order_id  customer_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329            1             1                   2                  8
# 1   2539329            1             1                   2                  8
# 2   2539329            1             1                   2                  8
# 3   2539329            1             1                   2                  8
# 4   2539329            1             1                   2                  8
#
#    days_since_prior_order  product_id  order_added_to_cart  reordered _merge
# 0                     NaN         196                    1          0   both
# 1                     NaN       14084                    2          0   both
# 2                     NaN       12427                    3          0   both
# 3                     NaN       26088                    4          0   both
# 4                     NaN       26405                    5          0   both

# %%
# dropping the _merge column from the df_ords_prods_combined dataset

df_ords_prods_combined = df_ords_prods_combined.drop(columns = ['_merge'])

# %%
# checking the shape of the df_ords_prods_combined data set

df_ords_prods_combined.shape
# Out:
# (32434489, 9)

# %% [markdown]
# ## 02. Merging the prods and ords_prods_combined data sets

# %%
# inner joining the df_prods and df_ords_prods_combined data set using product_id

df_merged_large = df_ords_prods_combined.merge(df_prods, on = ['product_id'], indicator = True)

# %%
df_merged_large
# Out:
#           order_id  customer_id  order_number  orders_day_of_week  \
# 0          2539329            1             1                   2
# 1          2398795            1             2                   3
# 2           473747            1             3                   3
# 3          2254736            1             4                   4
# 4           431534            1             5                   4
# ...            ...          ...           ...                 ...
# 32433025   1320836       202557            17                   2
# 32433026     31526       202557            18                   5
# 32433027    758936       203436             1                   2
# 32433028   2745165       203436             2                   3
# 32433029   3093936       205420             1                   4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# 1                         7                    15.0         196
# 2                        12                    21.0         196
# 3                         7                    29.0         196
# 4                        15                    28.0         196
# ...                     ...                     ...         ...
# 32433025                 15                     1.0       43553
# 32433026                 11                     3.0       43553
# 32433027                  7                     NaN       42338
# 32433028                  5                    15.0       42338
# 32433029                 14                     NaN       28818
#
#           order_added_to_cart  reordered                   product_name  \
# 0                           1          0                           Soda
# 1                           1          1                           Soda
# 2                           1          1                           Soda
# 3                           1          1                           Soda
# 4                           1          1                           Soda
# ...                       ...        ...                            ...
# 32433025                    2          1            Orange Energy Shots
# 32433026                    2          1            Orange Energy Shots
# 32433027                    4          0          Zucchini Chips, Pesto
# 32433028                   16          1          Zucchini Chips, Pesto
# 32433029                    8          0  Hot Oatmeal Multigrain Raisin
#
#           aisle_id  department_id  prices _merge
# 0               77              7     9.0   both
# 1               77              7     9.0   both
# 2               77              7     9.0   both
# 3               77              7     9.0   both
# 4               77              7     9.0   both
# ...            ...            ...     ...    ...
# 32433025        64              7     3.7   both
# 32433026        64              7     3.7   both
# 32433027        50             19     6.9   both
# 32433028        50             19     6.9   both
# 32433029       130             14    10.3   both
#
# [32433030 rows x 14 columns]

# %%
# checking counts on merge

df_merged_large['_merge'].value_counts()
# Out:
# both          32433030
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
# dropping _merge column 

df_merged_large = df_merged_large.drop(columns = ['_merge'])

# %%
df_merged_large.head()
# Out:
#    order_id  customer_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329            1             1                   2                  8
# 1   2398795            1             2                   3                  7
# 2    473747            1             3                   3                 12
# 3   2254736            1             4                   4                  7
# 4    431534            1             5                   4                 15
#
#    days_since_prior_order  product_id  order_added_to_cart  reordered  \
# 0                     NaN         196                    1          0
# 1                    15.0         196                    1          1
# 2                    21.0         196                    1          1
# 3                    29.0         196                    1          1
# 4                    28.0         196                    1          1
#
#   product_name  aisle_id  department_id  prices
# 0         Soda        77              7     9.0
# 1         Soda        77              7     9.0
# 2         Soda        77              7     9.0
# 3         Soda        77              7     9.0
# 4         Soda        77              7     9.0

# %% [markdown]
# ## 03. Consistency checks on merged data set

# %%
#checking for missing values

df_merged_large.isnull().sum()
# Out:
# order_id                        0
# customer_id                     0
# order_number                    0
# orders_day_of_week              0
# order_hour_of_day               0
# days_since_prior_order    2077979
# product_id                      0
# order_added_to_cart             0
# reordered                       0
# product_name                28171
# aisle_id                        0
# department_id                   0
# prices                          0
# dtype: int64

# %%
# changed all the missing product_name values to "unknown"
df_merged_large ['product_name'].fillna('unknown', inplace=True)

# %%
df_merged_large.isnull().sum()
# Out:
# order_id                        0
# customer_id                     0
# order_number                    0
# orders_day_of_week              0
# order_hour_of_day               0
# days_since_prior_order    2077979
# product_id                      0
# order_added_to_cart             0
# reordered                       0
# product_name                    0
# aisle_id                        0
# department_id                   0
# prices                          0
# dtype: int64

# %%
# checking for duplicates ...looks like there are not duplicates

df_merged_large_dups= df_merged_large[df_merged_large.duplicated()]
df_merged_large_dups
# Out:
# Empty DataFrame
# Columns: [order_id, customer_id, order_number, orders_day_of_week, order_hour_of_day, days_since_prior_order, product_id, order_added_to_cart, reordered, product_name, aisle_id, department_id, prices]
# Index: []

# %%
df_merged_large.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))
