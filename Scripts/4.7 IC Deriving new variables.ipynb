# %% [markdown]
# ## Contents
#
# 01. If-Statements with User-Defined Functions
# 02. If-Statements with the loc() function
# 03. If-statements with For-Loops

# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'/Users/lindazhang/Instacart Basket Analysis'
ords_prods_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %% [markdown]
# ## 01. If-Statements with User-Defined Functions

# %% [markdown]
# User-defined functions alows the user to define the kind of result they want and write the appropriate code to achieve it.
#
# The basic structure of a user-defined function is as follows:
#
# 1. A definition of the name and arguments the function will take
# 2. What the function is meant to do

# %% [markdown]
# The function starts with a definition, def. In the definition, the function is given a descriptive name: add_num(). Also, two arguments, x and y, are designated. This tells Python to always expect two arguments when this function is called.
#
# After the definition comes the body, which is where you tell the function what to do. Here, the two arguments, x and y, are added and assigned to a new variable, sum. Finally, sum is returned (the value of sum is printed). What the function below will do, then, is add the two numbers you give it and return the sum.

# %%
#define function 

def add_num(x,y):
    sum = x + y
    return sum

# run function

add_num(9, 11)
# Out:
# 20

# %%
# This creates a subset of ords_prods_merged that includes the first one millions rows
# Colon before a row number would pull all the rows before the number. Colon 
#after would pull all the rows after a row number. 

df = ords_prods_merged [:1000000]

# %%
df.head()
# Out:
#    order_id  customer_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329            1             1                   2                  8
# 1   2398795            1             2                   3                  7
# 2    473747            1             3                   3                 12
# 3   2254736            1             4                   4                  7
# 4    431534            1             5                   4                 15
#
#    days_since_prior_order  product_id  order_added_to_cart  reordered  \
# 0                     NaN         196                    1          0
# 1                    15.0         196                    1          1
# 2                    21.0         196                    1          1
# 3                    29.0         196                    1          1
# 4                    28.0         196                    1          1
#
#   product_name  aisle_id  department_id  prices
# ...

# %% [markdown]
# Define a function called price_label that would look at each row in a dataframe. Row in parenthesis is a standard argument telling the function to look at each row within the dataframe.
#
# If the value within the “prices” column within the given row is less than or equal to 5, then return the string “Low-range product.”
#
# Or else, if the value within the “prices” column within the given row is greater than 5 and less than or equal to 15, then return the string “Mid-range product.”
#
# Or else, if the value of the “prices” column within the given row is greater than 15, then return the string “High-range product.”
#
# Or else, return the string “Not enough data.”

# %%
# define function to sort price ranges

def price_label (row):
    if row['prices'] <= 5: 
        return 'Low-range product'
    elif (row['prices']>5) and (row['prices']<=15):
        return 'Mid-range product'
    elif row['prices'] >= 15:
        return 'High range'
    else: 
        return 'Not enough data'

# %% [markdown]
# Below is the function you would write to run price_label(row).
#
# Rather than calling the df dataframe by itself, the syntax df['price_range'] has been used. This creates a new column within the df dataframe called “price_range” and designates it as the location for your labels. On the right side of the equals sign comes the code that actually runs your new function: df.apply(price_label, axis=1).
#
# It’s telling Python to apply the price_label function on axis=1. This axis = 1 stands for “rows,” so it’s essentially telling Python to apply the function to all rows within the dataframe. (Conversely, axis = 0 would refer to all columns within the dataframe.)

# %%
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# /var/folders/j6/vcs2ps6j3pl6z1p5390gh8h00000gn/T/ipykernel_3537/2848743372.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
# count the number of products in each price range

df['price_range'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range, dtype: int64

# %%
df['prices'].max()
# Out:
# 14.8

# %% [markdown]
# ## 02. If-Statements with the loc() function

# %% [markdown]
# By using loc(), you can apply the conditional logic of an if-statement to a function without explicitly creating an if-else construct.
#
# Loc() is preferred over the method used above because it is much faster. This is because the loc() function applies the conditional filters before searching through the dataframe, while your user-defined function searched through the entire dataframe, then determined where to set the filters.

# %% [markdown]
# Below, from left to right, the loc() function is being called on the df dataframe. Within the brackets is the if statement. “if the values in the ‘prices’ column of the df dataframe are greater than 15.”
#
# After the comma comes the implied “then.” Here, a new column called “price_range_loc” is being set equal to the string “High-range product.”

# %%
# using the loc() function

df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# /var/folders/j6/vcs2ps6j3pl6z1p5390gh8h00000gn/T/ipykernel_3537/3278346240.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range_loc, dtype: int64

# %%
# Using the loc() function for the entire ords_prods_merged dataset

# %%
ords_prods_merged.loc[ords_prods_merged['prices'] > 15, 'price_range'] = 'High-range product'

# %%
ords_prods_merged.loc[(ords_prods_merged['prices'] <= 15) & (ords_prods_merged['prices'] > 5), 'price_range'] = 'Mid-range product'

# %%
ords_prods_merged.loc[ords_prods_merged ['prices'] <= 5, 'price_range'] = 'Low-range product'

# %%
ords_prods_merged['price_range'].value_counts(dropna = False)
# Out:
# Mid-range product     21889009
# Low-range product     10126339
# High-range product      417682
# Name: price_range, dtype: int64

# %% [markdown]
# ## 03. If-statements with For-Loops

# %% [markdown]
# For-loops, as their name implies, are loops for running the same block of code multiple times. They’re used to perform the same function on multiple elements, for instance, by running through an entire dataframe and performing a function on each row within that dataframe.
#
# This method is faster than a user-defined function as well because you’re only looping through one column of your dataframe, which will greatly speed up the performance (your user-defined function had to search through the entire dataframe).

# %%
# Check for the frequnecy of orders on each day of the week. Looks like Saturday (0) is the busiest day of the week.
# Wednesday (4) is the slowest day of the week. 

ords_prods_merged['orders_day_of_week'].value_counts(dropna = False)
# Out:
# 0    6209410
# 1    5665604
# 6    4500101
# 2    4217610
# 5    4209334
# 3    3843929
# 4    3787042
# Name: orders_day_of_week, dtype: int64

# %% [markdown]
# Below we're creating a new column “busiest day,” that will contain one of three different values: “Busiest day,” “Least busy,” and “Regularly busy” using a for-loop. The loop will run through every row in the “orders_day_of_the_week” column, compare the value in it with what we know are the busiest and slowest days, and assign it the corresponding string value.

# %% [markdown]
# The first step is to create an empty list, result. This will act as the empty shell, into which you can place the results from your loop. Then comes the loop itself. Here, you’re telling Python that for each value within the “orders_day_of_the_week” column, you want to do something.
#
# If the value in that row is equal to 0, a string value of “Busiest day” is appended to your currently blank result list. If not, and if the value is equal to 4, a string value of “Least busy” is appended to the result list. And finally, if neither of the above conditions have been met, then a string value of “Regularly busy” is appended to the result list.
#
# Note "value" is simply acting as a placeholder and you could call it anything (oftentimes, an x is used, like in the simple loop you went through earlier).Value below represents every possible value that could exist within the “orders_day_of_the_week” column.

# %%
result = []

for value in ords_prods_merged["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
# combine result with the dataframe

ords_prods_merged ['busiest_day'] = result

# %%
ords_prods_merged.head()
# Out:
#    order_id  customer_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329            1             1                   2                  8
# 1   2398795            1             2                   3                  7
# 2    473747            1             3                   3                 12
# 3   2254736            1             4                   4                  7
# 4    431534            1             5                   4                 15
#
#    days_since_prior_order  product_id  order_added_to_cart  reordered  \
# 0                     NaN         196                    1          0
# 1                    15.0         196                    1          1
# 2                    21.0         196                    1          1
# 3                    29.0         196                    1          1
# 4                    28.0         196                    1          1
#
#   product_name  aisle_id  department_id  prices        price_range  \
# ...

# %%
ords_prods_merged['busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    22436578
# Busiest day        6209410
# Least busy         3787042
# Name: busiest_day, dtype: int64

# %%
# identifying the 2 busiest and 2 slowest days

result2 = []

for value in ords_prods_merged['orders_day_of_week']:
  if value in [0,1]:
    result2.append("Busiest days")
  elif value in [3,4]:
    result2.append("Slowest days")
  else:
    result2.append("Regularly busy")

# %%
# combine result with the dataframe

ords_prods_merged ['busiest_days'] = result2

# %%
ords_prods_merged.head()
# Out:
#    order_id  customer_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329            1             1                   2                  8
# 1   2398795            1             2                   3                  7
# 2    473747            1             3                   3                 12
# 3   2254736            1             4                   4                  7
# 4    431534            1             5                   4                 15
#
#    days_since_prior_order  product_id  order_added_to_cart  reordered  \
# 0                     NaN         196                    1          0
# 1                    15.0         196                    1          1
# 2                    21.0         196                    1          1
# 3                    29.0         196                    1          1
# 4                    28.0         196                    1          1
#
#   product_name  aisle_id  department_id  prices        price_range  \
# ...

# %%
ords_prods_merged['busiest_days'].value_counts(dropna = False)
# Out:
# Regularly busy    12927045
# Busiest days      11875014
# Slowest days       7630971
# Name: busiest_days, dtype: int64

# %%
# checking the frequency of orders by hour 

ords_prods_merged['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    2764288
# 11    2738483
# 14    2691448
# 15    2664420
# 13    2663169
# 12    2620719
# 16    2537358
# 9     2456591
# 17    2089385
# 8     1719888
# 18    1637858
# 19    1259335
# 20     976991
# 7      891900
# 21     796341
# 22     634715
# 23     402593
# 6      290763
# 0      218925
# 1      115780
# 5       88054
# 2       69429
# 4       53280
# 3       51317
# Name: order_hour_of_day, dtype: int64

# %%
# grouping hours into time periods of the day

hour = []

for x in ords_prods_merged['order_hour_of_day']:
  if x in range (0,6):
    hour.append("12am-5am")
  elif x in range (6,12):
    hour.append("6am-11am")
  elif x in range (12,18):
    hour.append("12pm-5pm")
  else:
    hour.append("6pm-11pm")

# %%
# merging the time periods to ords_prods_merged 

ords_prods_merged ['period_of_day'] = hour

# %%
ords_prods_merged.head()
# Out:
#    order_id  customer_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329            1             1                   2                  8
# 1   2398795            1             2                   3                  7
# 2    473747            1             3                   3                 12
# 3   2254736            1             4                   4                  7
# 4    431534            1             5                   4                 15
#
#    days_since_prior_order  product_id  order_added_to_cart  reordered  \
# 0                     NaN         196                    1          0
# 1                    15.0         196                    1          1
# 2                    21.0         196                    1          1
# 3                    29.0         196                    1          1
# 4                    28.0         196                    1          1
#
#   product_name  aisle_id  department_id  prices        price_range  \
# ...

# %%
# Busiest period of day is 12pm - 5pm. Slowest period of day is 12am-5am. 

ords_prods_merged['period_of_day'].value_counts(dropna = False)
# Out:
# 12pm-5pm    15266499
# 6am-11am    10861913
# 6pm-11pm     5707833
# 12am-5am      596785
# Name: period_of_day, dtype: int64

# %%
# label busiest periods of the day 

busiest_periods = []

for x in ords_prods_merged['order_hour_of_day']:
  if x in range (12,18):
    busiest_periods.append("Most orders")
  elif x in range (0,6):
    busiest_periods.append("Fewest orders")
  else:
    busiest_periods.append("Average orders")

# %%
# merging busiest_periods to ords_prods_merged

ords_prods_merged ['busiest_periods'] = busiest_periods

# %%
# checking values counts of busiest_period column

ords_prods_merged['busiest_periods'].value_counts(dropna = False)
# Out:
# Average orders    16569746
# Most orders       15266499
# Fewest orders       596785
# Name: busiest_periods, dtype: int64

# %%
ords_prods_merged.head ()
# Out:
#    order_id  customer_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329            1             1                   2                  8
# 1   2398795            1             2                   3                  7
# 2    473747            1             3                   3                 12
# 3   2254736            1             4                   4                  7
# 4    431534            1             5                   4                 15
#
#    days_since_prior_order  product_id  order_added_to_cart  reordered  \
# 0                     NaN         196                    1          0
# 1                    15.0         196                    1          1
# 2                    21.0         196                    1          1
# 3                    29.0         196                    1          1
# 4                    28.0         196                    1          1
#
#   product_name  aisle_id  department_id  prices        price_range  \
# ...

# %%
ords_prods_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))
